# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: openai==1.44.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 1)) (1.44.1)
# Requirement already satisfied: graphdatascience in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: retry==0.9.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (0.9.2)
# Requirement already satisfied: streamlit==1.23.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 4)) (1.23.1)
# Requirement already satisfied: streamlit-chat==0.0.2.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.0.2.2)
# Requirement already satisfied: streamlit-chat-media==0.0.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: plotly==5.15.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 9)) (5.15.0)
# Requirement already satisfied: altair<5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (4.2.2)
# Requirement already satisfied: python-dotenv==1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (1.0.1)
# Requirement already satisfied: langchain==0.2.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (0.2.16)
# Requirement already satisfied: langchain-community==0.2.16 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (0.2.16)
# Requirement already satisfied: langchain-core==0.2.39 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (0.2.39)
# Requirement already satisfied: langchain-experimental==0.0.65 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (0.0.65)
# Requirement already satisfied: langchain-openai==0.1.23 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (0.1.23)
# Requirement already satisfied: langsmith==0.1.117 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (0.1.117)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (2.9.1)
# Requirement already satisfied: sniffio in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (4.66.5)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from openai==1.44.1->-r requirements.txt (line 1)) (4.12.2)
# Requirement already satisfied: decorator>=3.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from retry==0.9.2->-r requirements.txt (line 3)) (1.11.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: cachetools<6,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (6.11.0)
# Requirement already satisfied: packaging<24,>=14.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (23.2)
# Requirement already satisfied: pillow<10,>=6.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (9.5.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (4.25.4)
# Requirement already satisfied: pyarrow>=4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (16.1.0)
# Requirement already satisfied: pympler<2,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (1.1)
# Requirement already satisfied: python-dateutil<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: rich<14,>=10.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (8.5.0)
# Requirement already satisfied: toml<2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: tzlocal<5,>=1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (4.3.1)
# Requirement already satisfied: validators<1,>=0.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (0.34.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from streamlit==1.23.1->-r requirements.txt (line 4)) (6.3.2)
# Requirement already satisfied: PyYAML>=5.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain==0.2.16->-r requirements.txt (line 12)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain==0.2.16->-r requirements.txt (line 12)) (2.0.34)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain==0.2.16->-r requirements.txt (line 12)) (3.10.5)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain==0.2.16->-r requirements.txt (line 12)) (0.2.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-community==0.2.16->-r requirements.txt (line 13)) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-core==0.2.39->-r requirements.txt (line 14)) (1.33)
# Requirement already satisfied: tiktoken<1,>=0.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langchain-openai==0.1.23->-r requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from langsmith==0.1.117->-r requirements.txt (line 17)) (3.10.7)
# Requirement already satisfied: multimethod<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from graphdatascience->-r requirements.txt (line 2)) (1.12)
# Requirement already satisfied: neo4j<6.0,>=4.4.12 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from graphdatascience->-r requirements.txt (line 2)) (5.26.0)
# Requirement already satisfied: textdistance<5.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from graphdatascience->-r requirements.txt (line 2)) (4.6.3)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: entrypoints in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5->-r requirements.txt (line 10)) (0.4)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5->-r requirements.txt (line 10)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5->-r requirements.txt (line 10)) (4.19.0)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from altair<5->-r requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.16->-r requirements.txt (line 12)) (1.11.1)
# Requirement already satisfied: idna>=2.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai==1.44.1->-r requirements.txt (line 1)) (3.8)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16->-r requirements.txt (line 13)) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16->-r requirements.txt (line 13)) (0.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 4)) (4.0.11)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.44.1->-r requirements.txt (line 1)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai==1.44.1->-r requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.44.1->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: zipp>=0.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from importlib-metadata<7,>=1.4->streamlit==1.23.1->-r requirements.txt (line 4)) (3.20.2)
# Requirement already satisfied: jsonpointer>=1.9 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.2.39->-r requirements.txt (line 14)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 10)) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 10)) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema>=3.0->altair<5->-r requirements.txt (line 10)) (0.9.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai==1.44.1->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai==1.44.1->-r requirements.txt (line 1)) (2.23.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->altair<5->-r requirements.txt (line 10)) (2.1.3)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil<3,>=2->streamlit==1.23.1->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.4->streamlit==1.23.1->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.4->streamlit==1.23.1->-r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 4)) (2.16.1)
# Requirement already satisfied: regex>=2022.1.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai==0.1.23->-r requirements.txt (line 16)) (2024.7.24)
# Requirement already satisfied: pytz-deprecation-shim in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tzlocal<5,>=1.1->streamlit==1.23.1->-r requirements.txt (line 4)) (0.1.0.post0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit==1.23.1->-r requirements.txt (line 4)) (5.0.1)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.11.0->streamlit==1.23.1->-r requirements.txt (line 4)) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.16->-r requirements.txt (line 13)) (1.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import openai
import json
from neo4j import GraphDatabase
import glob
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, HumanMessagePromptTemplate, PromptTemplate
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# %%
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
neo4j_url = os.getenv("NEO4J_URL")
neo4j_user = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")
gds = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))
gds.verify_connectivity()

# %% [markdown]
# **Constructing knowledge graph**

# %%
def gpt_call(text):
    extraction_template = """
    From the weekly report below, extract (as many as possible) relationships between environmental events in Thai by following these steps:
    0. Check the top of the document for the date of the report, as you might need it
    1. Identify environmental events that are associated with other resulting events and generate as comma-separated format:
        id:string, name:string, date:string, place:string 
        # 'id' must be unique among events; include the date from the 0. step to 'id'
        # 'name' of the event should be a comprehensive description of the event
        # 'name' of the event should not include causation or date
        # if the event is not associated with numerical date, then assign the date from the 0. step

    2. Generate each relationship as triples of head, relationship, and tail. To refer the head and tail entity, use their respective 'id' property.
    Only generate casuation relationships.
    Follow the format: event|CAUSES|event

    3. The output should look like:  # put a set of curly brackets around the final output
    "events": ["id":string, "name":string, "date":string, "place":string], # for each event, put a set of curly brackets around
    "relationships": ["eventid|CAUSES|eventid"] 

    Weekly report:
    {report}
    """

    extraction_prompt = PromptTemplate.from_template(extraction_template) 
    llm = ChatOpenAI(model="gpt-4o",
                     max_tokens=15000)
    prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a helpful environmental, water expert who extracts information from reports."),
        HumanMessagePromptTemplate.from_template("{report}")
    ]
)

    chain = {"report": RunnablePassthrough() } | extraction_prompt | prompt | llm | StrOutputParser()
    return chain.invoke(text)

def extract_entities_relationships():
    files = glob.glob("data/*.md")
    
    result = []
    for i, file in enumerate(files):
        print(f"Processing file {i + 1}")
        try:
            with open(file, "r") as f:
                report = f.read()
                res = gpt_call(report)

                clean = res.replace('```json', '').replace('```', '').strip()
                j = json.loads(clean)

                result.append(j)
        except Exception as e:
            print(f"Error processing file {i + 1}: {str(e)}")
    return result

# %%
def generate_cypher(json_obj):
    label = "Event"
    event_statements = []
    r_statements = []
    label_map = {}

    for i, obj in enumerate(json_obj):
        for event in obj["events"]:
            id = event["id"]
            id = id.replace("_", "").replace("-", "")
            properties = {k:v for k,v in event.items() if k not in ["id"]}

            cypher = f'MERGE (n:{label} {{id: "{id}"}})'
            if properties:
                props_str = ", ".join(
                    [f'n.{key} = "{val}"' for key, val in properties.items()]
                )
                cypher += f" ON CREATE SET {props_str}"
            event_statements.append(cypher)
            label_map[id] = label
        
        for rs in obj["relationships"]:
            src_id, rs_type, tgt_id = rs.split("|")
            src_id = src_id.replace("-", "").replace("_", "")
            tgt_id = tgt_id.replace("-", "").replace("_", "")

            src_label = label_map[src_id]
            tgt_label = label_map[tgt_id]

            cypher = f'MERGE (a:{src_label} {{id: "{src_id}"}}) MERGE (b:{tgt_label} {{id: "{tgt_id}"}}) MERGE (a)-[:{rs_type}]->(b)'
            r_statements.append(cypher)
        
    with open("cyphers.txt", "w") as outfile:
            outfile.write("\n".join(event_statements + r_statements))

    return event_statements + r_statements

# %%
def ingestion_pipeline():
    with open("test.json", "r", encoding="utf-8") as f:
        data = f.read()
        obj = json.loads(data)
    
    cypher = generate_cypher(obj)
    for i, st in enumerate(cypher):
        print(f"Executing cypher statement {i + 1}")
        try:
            gds.execute_query(st)
        except Exception as e:
            print(f"Error executing cypher statement {i + 1}: {str(e)}")

# %%
# already executed 
# results = extract_entities_relationships()
# with open("test.json", "w", encoding="utf-8") as f:
#     json.dump(results, f, ensure_ascii=False, indent=4)
# ingestion_pipeline()
